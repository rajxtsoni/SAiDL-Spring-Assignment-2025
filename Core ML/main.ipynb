# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
from torch.cuda.amp import autocast, GradScaler 

# Data Preparation with Noise

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

def introduce_symmetric_noise_inplace(dataset, noise_rate):
    labels = np.array(dataset.targets)
    num_classes = len(set(labels))
    n_samples = len(labels)
    n_noisy = int(noise_rate * n_samples)
    noisy_indices = np.random.choice(n_samples, n_noisy, replace=False)
    for idx in noisy_indices:
        current_label = labels[idx]
        new_label = np.random.choice([i for i in range(num_classes) if i != current_label])
        labels[idx] = new_label
    dataset.targets = labels.tolist()
    return dataset

def introduce_asymmetric_noise_inplace(dataset, noise_rate):
    
    asym_map = {
        0: 0,  # airplane -> airplane (stays same)
        1: 9,  # automobile -> truck
        9: 1,  # truck -> automobile
        2: 0,  
        3: 5,  
        5: 3,  
        4: 7,  
        6: 6,  
        7: 7,  
        8: 8   
    }

    labels = np.array(dataset.targets)
    n_samples = len(labels)

    # For each sample, let's flip label with probability noise_rate
    flip_mask = np.random.rand(n_samples) < noise_rate
    for i in range(n_samples):
        if flip_mask[i]:
            current_label = labels[i]
            labels[i] = asym_map[current_label]

    dataset.targets = labels.tolist()
    return dataset


noise_rates = [0.2, 0.4, 0.6, 0.8]
asymmetric_noise_rates = [0.1, 0.25, 0.4]

noisy_datasets = {}
for rate in noise_rates:
    dataset_copy = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
    noisy_datasets[rate] = introduce_symmetric_noise_inplace(dataset_copy, rate)

asymmetric_noisy_datasets = {}
for rate in asymmetric_noise_rates:
    dataset_copy = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform
    )
    asymmetric_noisy_datasets[rate] = introduce_asymmetric_noise_inplace(dataset_copy, rate)

def get_dataloader(dataset, batch_size=64):
    return torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)


noisy_dataloaders = {rate: get_dataloader(noisy_datasets[rate]) for rate in noise_rates}
asymmetric_noisy_dataloaders = {rate: get_dataloader(asymmetric_noisy_datasets[rate]) for rate in asymmetric_noise_rates}

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = get_dataloader(testset, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Model and Loss Function Definitions

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 128, 3, padding=1)
        self.conv2 = nn.Conv2d(128, 128, 3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
        self.conv4 = nn.Conv2d(256, 256, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.bn_conv1 = nn.BatchNorm2d(128)
        self.bn_conv2 = nn.BatchNorm2d(128)
        self.bn_conv3 = nn.BatchNorm2d(256)
        self.bn_conv4 = nn.BatchNorm2d(256)
        self.dropout_conv = nn.Dropout2d(p=0.3)
        self.dropout = nn.Dropout(p=0.5)

        # Using a dummy tensor to compute the correct input size for fc1
        dummy_input = torch.zeros(1, 3, 32, 32)  
        out = self._get_conv_output(dummy_input)

        self.fc1 = nn.Linear(out, 1024)  # Dynamically determined
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 10)

    def _get_conv_output(self, x):
        x = self.pool(F.relu(self.bn_conv1(self.conv1(x))))
        x = self.pool(F.relu(self.bn_conv2(self.conv2(x))))
        x = self.dropout_conv(x)
        x = self.pool(F.relu(self.bn_conv3(self.conv3(x))))
        x = self.pool(F.relu(self.bn_conv4(self.conv4(x))))
        x = self.dropout_conv(x)
        return int(torch.prod(torch.tensor(x.shape[1:])))  # Compute flattened size dynamically

    def forward(self, x):
        x = self.pool(F.relu(self.bn_conv1(self.conv1(x))))
        x = self.pool(F.relu(self.bn_conv2(self.conv2(x))))
        x = self.dropout_conv(x)
        x = self.pool(F.relu(self.bn_conv3(self.conv3(x))))
        x = self.pool(F.relu(self.bn_conv4(self.conv4(x))))
        x = self.dropout_conv(x)

        x = x.view(x.size(0), -1)  # Correctly flatten dynamically

        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        return self.fc3(x)


# Define Focal Loss
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
    def forward(self, inputs, targets):
        ce_loss = nn.CrossEntropyLoss(reduction='none')(inputs, targets)
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss
        return focal_loss.mean() if self.reduction == 'mean' else focal_loss.sum()

# Define Normalized Cross-Entropy Loss (NCE)
class NormalizedCrossEntropy(nn.Module):
    def __init__(self):
        super(NormalizedCrossEntropy, self).__init__()

    def forward(self, inputs, targets):
        """
        inputs:  [batch_size, num_classes] raw logits
        targets: [batch_size] integer class labels
        """
        batch_size = inputs.size(0)
        log_probs = F.log_softmax(inputs, dim=1)  # shape (B, C)

        # Numerator:  -log p(y|x)
        # i.e. the usual cross-entropy for the correct class only
        ce_per_sample = -log_probs[torch.arange(batch_size), targets]

        # Denominator: sum_k [-log p(k|x)]
        # i.e. the negative log-likelihood of all classes, then summed
        sum_neglog = -torch.sum(log_probs, dim=1)  # shape (B,)

        # Ratio
        ratio = ce_per_sample / (sum_neglog + 1e-12)

        return ratio.mean()

# Define Normalized Focal Loss (NFL)
class NormalizedFocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        super(NormalizedFocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        num_classes = inputs.shape[1]
        normalization_factor = torch.log(torch.tensor(num_classes, dtype=torch.float, device=inputs.device) + 1e-8)

        ce_loss = nn.CrossEntropyLoss(reduction='none')(inputs, targets)
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss

        focal_loss = focal_loss / normalization_factor  # Normalize final loss
        return focal_loss.mean() if self.reduction == 'mean' else focal_loss.sum()

# Define Mean Absolute Error (MAE) Loss 
class MAELoss(nn.Module):
    def __init__(self):
        super(MAELoss, self).__init__()

    def forward(self, inputs, targets):
        num_classes = inputs.shape[1]
        one_hot_targets = F.one_hot(targets, num_classes=num_classes).float()

        probs = F.softmax(inputs, dim=1)  # Convert logits to probabilities
        return torch.mean(torch.abs(one_hot_targets - probs))

# Define Reverse Cross-Entropy (RCE) Loss
class RCELoss(nn.Module):
    def __init__(self, A=-4.0):
        super(RCELoss, self).__init__()
        self.A = A  # clamp for log(0)

    def forward(self, inputs, targets):
        """
        inputs:  [batch_size, num_classes] raw logits
        targets: [batch_size] integer class labels
        """
        batch_size, num_classes = inputs.size()
        p = F.softmax(inputs, dim=1) 

        log_q = inputs.new_full((batch_size, num_classes), self.A)
        log_q[torch.arange(batch_size), targets] = 0.0

        rce_per_sample = -torch.sum(p * log_q, dim=1)
        return rce_per_sample.mean()


class APLLoss(nn.Module):
    
    def __init__(self, alpha_loss, passive_loss, alpha=1.0, beta=1.0):
        super(APLLoss, self).__init__()
        self.alpha_loss = alpha_loss   # e.g. NormalizedCrossEntropy() [active]
        self.passive_loss = passive_loss  # e.g. RCELoss() or MAELoss() [passive]
        self.alpha = alpha
        self.beta = beta

    def forward(self, outputs, labels):
        active_term = self.alpha_loss(outputs, labels)
        passive_term = self.passive_loss(outputs, labels)

        return self.alpha * active_term + self.beta * passive_term


loss_fns = {
    'CE': nn.CrossEntropyLoss(),
    'FL': FocalLoss(),
    'NCE': NormalizedCrossEntropy(),   # ratio-based NCE
    'NFL': NormalizedFocalLoss(),      # ratio-based NFL if you have it
    'MAE': MAELoss(),
    'RCE': RCELoss(A=-4.0),            # "true" reversed, with clamp
    'APL_NCE_RCE': APLLoss(NormalizedCrossEntropy(), RCELoss(A=-4.0)),
    'APL_NFL_MAE': APLLoss(NormalizedFocalLoss(), MAELoss()),
}

loss_lrs = {
    'CE': 0.01,       # Cross-Entropy (CE)
    'FL': 0.01,       # Focal Loss (FL)
    'NCE': 0.02,      # Normalized Cross-Entropy (NCE) (slightly higher due to normalization)
    'NFL': 0.02,      # Normalized Focal Loss (NFL)
    'MAE': 0.005,     # Mean Absolute Error (MAE) (lower as it's sensitive to scale)
    'RCE': 0.005,     # Reverse Cross-Entropy (RCE) (similar to MAE)
    'APL_NCE_RCE': 0.01,  # Active-Passive Loss with NCE + RCE
    'APL_NFL_MAE': 0.01   # Active-Passive Loss with NFL + MAE
}


def train_model(loss_fn, trainloader, lr, epochs=25):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = SimpleCNN().to(device)
    # Using SGD with momentum and weight decay
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=5e-4)
    # Using a cosine annealing scheduler over the full number of epochs
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    loss_history = []

    for epoch in range(epochs):
        running_loss = 0.0
        model.train()
        for images, labels in trainloader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = loss_fn(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        scheduler.step()
        avg_loss = running_loss / len(trainloader)
        loss_history.append(avg_loss)
        print(f"Epoch {epoch+1} | Loss: {avg_loss:.4f}")

    return model, loss_history



def evaluate_model(model, testloader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.cuda(), labels.cuda()
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total

results = {}
for noise_rate in noise_rates:
    noisy_trainloader = noisy_dataloaders[noise_rate]
    for loss_name, loss_fn in loss_fns.items():
        print(f"Training {loss_name} on noise rate {noise_rate}")
        model, losses = train_model(loss_fn, noisy_trainloader, loss_lrs[loss_name])
        acc = evaluate_model(model, testloader)
        results[(loss_name, noise_rate)] = (acc, losses)
        print(f"{loss_name} Accuracy at {noise_rate} noise level: {acc:.2f}%")
asymmetric_results = {}
for noise_rate in asymmetric_noise_rates:
    noisy_trainloader = asymmetric_noisy_dataloaders[noise_rate]
    for loss_name, loss_fn in loss_fns.items():
        print(f"[Asymmetric] Training {loss_name} at noise rate {noise_rate}")
        model, losses = train_model(loss_fn, noisy_trainloader, loss_lrs[loss_name])
        acc = evaluate_model(model, testloader)
        asymmetric_results[(loss_name, noise_rate)] = (acc, losses)
        print(f"[Asymmetric] {loss_name} Accuracy at {noise_rate} noise level: {acc:.2f}%")



import matplotlib.pyplot as plt

def plot_results(results, noise_rates, loss_fns):
    loss_names = list(loss_fns.keys())

    groups = [
        loss_names[:2],  
        [loss_names[2], loss_names[5], loss_names[6]],  
        [loss for loss in loss_names if loss not in loss_names[:2] and loss not in [loss_names[2], loss_names[5], loss_names[6]]]  # Remaining
    ]

    plt.figure(figsize=(8, 12))

    for i, group in enumerate(groups, 1):
        plt.subplot(3, 1, i)
        for loss_name in group:
            accuracies = [results[(loss_name, noise_rate)][0] for noise_rate in noise_rates]
            plt.plot(noise_rates, accuracies, marker='o', label=loss_name)

        plt.xlabel("Noise Rate")
        plt.ylabel("Accuracy (%)")
        plt.title(f"Impact of Noise Rate on Accuracy - Graph {i}")
        plt.legend()
        plt.grid()

    plt.tight_layout()
    plt.show()

plot_results(results, noise_rates, loss_fns)
plot_results(asymmetric_results, asymmetric_noise_rates, loss_fns)
# Out:
# Training CE on noise rate 0.2
# Epoch 1 | Loss: 1.9593
# Epoch 2 | Loss: 1.7814
# Epoch 3 | Loss: 1.6920
# Epoch 4 | Loss: 1.6281
# Epoch 5 | Loss: 1.5783
# Epoch 6 | Loss: 1.5257
# Epoch 7 | Loss: 1.4810
# Epoch 8 | Loss: 1.4391
# Epoch 9 | Loss: 1.4040
# Epoch 10 | Loss: 1.3621
# Epoch 11 | Loss: 1.3280
# Epoch 12 | Loss: 1.2895
# Epoch 13 | Loss: 1.2540
# Epoch 14 | Loss: 1.2157
# Epoch 15 | Loss: 1.1823
# Epoch 16 | Loss: 1.1395
# Epoch 17 | Loss: 1.0939
# Epoch 18 | Loss: 1.0570
# Epoch 19 | Loss: 1.0109
# Epoch 20 | Loss: 0.9684
# Epoch 21 | Loss: 0.9312
# Epoch 22 | Loss: 0.8918
# Epoch 23 | Loss: 0.8611
# Epoch 24 | Loss: 0.8431
# Epoch 25 | Loss: 0.8305
# CE Accuracy at 0.2 noise level: 78.86%
# Training FL on noise rate 0.2
# Epoch 1 | Loss: 1.4879
# Epoch 2 | Loss: 1.3282
# Epoch 3 | Loss: 1.2506
# Epoch 4 | Loss: 1.2000
# Epoch 5 | Loss: 1.1514
# Epoch 6 | Loss: 1.1112
# Epoch 7 | Loss: 1.0692
# Epoch 8 | Loss: 1.0379
# Epoch 9 | Loss: 1.0097
# Epoch 10 | Loss: 0.9764
# Epoch 11 | Loss: 0.9443
# Epoch 12 | Loss: 0.9144
# Epoch 13 | Loss: 0.8910
# Epoch 14 | Loss: 0.8633
# Epoch 15 | Loss: 0.8331
# Epoch 16 | Loss: 0.8034
# Epoch 17 | Loss: 0.7776
# Epoch 18 | Loss: 0.7463
# Epoch 19 | Loss: 0.7183
# Epoch 20 | Loss: 0.6851
# Epoch 21 | Loss: 0.6623
# Epoch 22 | Loss: 0.6340
# Epoch 23 | Loss: 0.6158
# Epoch 24 | Loss: 0.6051
# Epoch 25 | Loss: 0.5935
# FL Accuracy at 0.2 noise level: 79.41%
# Training NCE on noise rate 0.2
# Epoch 1 | Loss: 0.0688
# Epoch 2 | Loss: 0.0446
# Epoch 3 | Loss: 0.0413
# Epoch 4 | Loss: 0.0398
# Epoch 5 | Loss: 0.0383
# Epoch 6 | Loss: 0.0374
# Epoch 7 | Loss: 0.0368
# Epoch 8 | Loss: 0.0364
# Epoch 9 | Loss: 0.0359
# Epoch 10 | Loss: 0.0356
# Epoch 11 | Loss: 0.0351
# Epoch 12 | Loss: 0.0345
# Epoch 13 | Loss: 0.0343
# Epoch 14 | Loss: 0.0338
# Epoch 15 | Loss: 0.0334
# Epoch 16 | Loss: 0.0329
# Epoch 17 | Loss: 0.0325
# Epoch 18 | Loss: 0.0321
# Epoch 19 | Loss: 0.0319
# Epoch 20 | Loss: 0.0315
# Epoch 21 | Loss: 0.0312
# Epoch 22 | Loss: 0.0309
# Epoch 23 | Loss: 0.0307
# Epoch 24 | Loss: 0.0305
# Epoch 25 | Loss: 0.0304
# NCE Accuracy at 0.2 noise level: 37.56%
# Training NFL on noise rate 0.2
# Epoch 1 | Loss: 0.6439
# Epoch 2 | Loss: 0.5700
# Epoch 3 | Loss: 0.5346
# Epoch 4 | Loss: 0.5087
# Epoch 5 | Loss: 0.4897
# Epoch 6 | Loss: 0.4719
# Epoch 7 | Loss: 0.4554
# Epoch 8 | Loss: 0.4403
# Epoch 9 | Loss: 0.4285
# Epoch 10 | Loss: 0.4143
# Epoch 11 | Loss: 0.4026
# Epoch 12 | Loss: 0.3894
# Epoch 13 | Loss: 0.3766
# Epoch 14 | Loss: 0.3625
# Epoch 15 | Loss: 0.3506
# Epoch 16 | Loss: 0.3353
# Epoch 17 | Loss: 0.3204
# Epoch 18 | Loss: 0.3043
# Epoch 19 | Loss: 0.2877
# Epoch 20 | Loss: 0.2688
# Epoch 21 | Loss: 0.2532
# Epoch 22 | Loss: 0.2363
# Epoch 23 | Loss: 0.2233
# Epoch 24 | Loss: 0.2151
# Epoch 25 | Loss: 0.2109
# NFL Accuracy at 0.2 noise level: 77.68%
# Training MAE on noise rate 0.2
# Epoch 1 | Loss: 0.1794
# Epoch 2 | Loss: 0.1752
# Epoch 3 | Loss: 0.1658
# Epoch 4 | Loss: 0.1570
# Epoch 5 | Loss: 0.1506
# Epoch 6 | Loss: 0.1446
# Epoch 7 | Loss: 0.1393
# Epoch 8 | Loss: 0.1354
# Epoch 9 | Loss: 0.1320
# Epoch 10 | Loss: 0.1296
# Epoch 11 | Loss: 0.1270
# Epoch 12 | Loss: 0.1253
# Epoch 13 | Loss: 0.1239
# Epoch 14 | Loss: 0.1224
# Epoch 15 | Loss: 0.1213
# Epoch 16 | Loss: 0.1201
# Epoch 17 | Loss: 0.1193
# Epoch 18 | Loss: 0.1186
# Epoch 19 | Loss: 0.1177
# Epoch 20 | Loss: 0.1171
# Epoch 21 | Loss: 0.1168
# Epoch 22 | Loss: 0.1163
# Epoch 23 | Loss: 0.1164
# Epoch 24 | Loss: 0.1164
# Epoch 25 | Loss: 0.1160
# MAE Accuracy at 0.2 noise level: 54.13%
# Training RCE on noise rate 0.2
# Epoch 1 | Loss: 3.1269
# Epoch 2 | Loss: 2.8267
# Epoch 3 | Loss: 2.7861
# Epoch 4 | Loss: 2.7348
# Epoch 5 | Loss: 2.7084
# Epoch 6 | Loss: 2.6954
# Epoch 7 | Loss: 2.6727
# Epoch 8 | Loss: 2.6472
# Epoch 9 | Loss: 2.6355
# Epoch 10 | Loss: 2.6150
# Epoch 11 | Loss: 2.5861
# Epoch 12 | Loss: 2.5566
# Epoch 13 | Loss: 2.5431
# Epoch 14 | Loss: 2.5195
# Epoch 15 | Loss: 2.5020
# Epoch 16 | Loss: 2.4742
# Epoch 17 | Loss: 2.4620
# Epoch 18 | Loss: 2.4387
# Epoch 19 | Loss: 2.4281
# Epoch 20 | Loss: 2.4165
# Epoch 21 | Loss: 2.4046
# Epoch 22 | Loss: 2.3925
# Epoch 23 | Loss: 2.3890
# Epoch 24 | Loss: 2.3812
# Epoch 25 | Loss: 2.3771
# RCE Accuracy at 0.2 noise level: 49.86%
# Training APL_NCE_RCE on noise rate 0.2
# Epoch 1 | Loss: 3.3134
# Epoch 2 | Loss: 3.1918
# Epoch 3 | Loss: 3.2201
# Epoch 4 | Loss: 3.2194
# Epoch 5 | Loss: 3.2278
# Epoch 6 | Loss: 3.2195
# Epoch 7 | Loss: 3.2163
# Epoch 8 | Loss: 3.2064
# Epoch 9 | Loss: 3.2119
# Epoch 10 | Loss: 3.1707
# Epoch 11 | Loss: 3.1090
# Epoch 12 | Loss: 3.1635
# Epoch 13 | Loss: 3.1122
# Epoch 14 | Loss: 3.0434
# Epoch 15 | Loss: 3.0520
# Epoch 16 | Loss: 2.9887
# Epoch 17 | Loss: 2.9642
# Epoch 18 | Loss: 2.9485
# Epoch 19 | Loss: 2.9241
# Epoch 20 | Loss: 2.8864
# Epoch 21 | Loss: 2.8562
# Epoch 22 | Loss: 2.8341
# Epoch 23 | Loss: 2.8240
# Epoch 24 | Loss: 2.8234
# Epoch 25 | Loss: 2.8183
# APL_NCE_RCE Accuracy at 0.2 noise level: 40.39%
# Training APL_NFL_MAE on noise rate 0.2
# Epoch 1 | Loss: 0.8090
# Epoch 2 | Loss: 0.7189
# Epoch 3 | Loss: 0.6792
# Epoch 4 | Loss: 0.6492
# Epoch 5 | Loss: 0.6287
# Epoch 6 | Loss: 0.6078
# Epoch 7 | Loss: 0.5913
# Epoch 8 | Loss: 0.5761
# Epoch 9 | Loss: 0.5616
# Epoch 10 | Loss: 0.5474
# Epoch 11 | Loss: 0.5340
# Epoch 12 | Loss: 0.5199
# Epoch 13 | Loss: 0.5087
# Epoch 14 | Loss: 0.4938
# Epoch 15 | Loss: 0.4812
# Epoch 16 | Loss: 0.4660
# Epoch 17 | Loss: 0.4509
# Epoch 18 | Loss: 0.4368
# Epoch 19 | Loss: 0.4222
# Epoch 20 | Loss: 0.4045
# Epoch 21 | Loss: 0.3895
# Epoch 22 | Loss: 0.3764
# Epoch 23 | Loss: 0.3674
# Epoch 24 | Loss: 0.3583
# Epoch 25 | Loss: 0.3542
# APL_NFL_MAE Accuracy at 0.2 noise level: 78.78%
# Training CE on noise rate 0.4
# Epoch 1 | Loss: 2.1665
# Epoch 2 | Loss: 2.0863
# Epoch 3 | Loss: 2.0455
# Epoch 4 | Loss: 2.0116
# Epoch 5 | Loss: 1.9847
# Epoch 6 | Loss: 1.9579
# Epoch 7 | Loss: 1.9319
# Epoch 8 | Loss: 1.9102
# Epoch 9 | Loss: 1.8881
# Epoch 10 | Loss: 1.8627
# Epoch 11 | Loss: 1.8391
# Epoch 12 | Loss: 1.8129
# Epoch 13 | Loss: 1.7922
# Epoch 14 | Loss: 1.7690
# Epoch 15 | Loss: 1.7366
# Epoch 16 | Loss: 1.7132
# Epoch 17 | Loss: 1.6823
# Epoch 18 | Loss: 1.6505
# Epoch 19 | Loss: 1.6142
# Epoch 20 | Loss: 1.5789
# Epoch 21 | Loss: 1.5411
# Epoch 22 | Loss: 1.5043
# Epoch 23 | Loss: 1.4714
# Epoch 24 | Loss: 1.4525
# Epoch 25 | Loss: 1.4395
# CE Accuracy at 0.4 noise level: 74.12%
# Training FL on noise rate 0.4
# Epoch 1 | Loss: 1.7061
# Epoch 2 | Loss: 1.6245
# Epoch 3 | Loss: 1.5873
# Epoch 4 | Loss: 1.5571
# Epoch 5 | Loss: 1.5310
# Epoch 6 | Loss: 1.5046
# Epoch 7 | Loss: 1.4849
# Epoch 8 | Loss: 1.4610
# Epoch 9 | Loss: 1.4370
# Epoch 10 | Loss: 1.4166
# Epoch 11 | Loss: 1.3939
# Epoch 12 | Loss: 1.3757
# Epoch 13 | Loss: 1.3530
# Epoch 14 | Loss: 1.3300
# Epoch 15 | Loss: 1.3118
# Epoch 16 | Loss: 1.2894
# Epoch 17 | Loss: 1.2643
# Epoch 18 | Loss: 1.2402
# Epoch 19 | Loss: 1.2153
# Epoch 20 | Loss: 1.1881
# Epoch 21 | Loss: 1.1588
# Epoch 22 | Loss: 1.1343
# Epoch 23 | Loss: 1.1129
# Epoch 24 | Loss: 1.0938
# Epoch 25 | Loss: 1.0854
# FL Accuracy at 0.4 noise level: 75.53%
# Training NCE on noise rate 0.4
# Epoch 1 | Loss: 0.0835
# Epoch 2 | Loss: 0.0637
# Epoch 3 | Loss: 0.0605
# Epoch 4 | Loss: 0.0589
# Epoch 5 | Loss: 0.0577
# Epoch 6 | Loss: 0.0569
# Epoch 7 | Loss: 0.0564
# Epoch 8 | Loss: 0.0560
# Epoch 9 | Loss: 0.0555
# Epoch 10 | Loss: 0.0550
# Epoch 11 | Loss: 0.0546
# Epoch 12 | Loss: 0.0545
# Epoch 13 | Loss: 0.0539
# Epoch 14 | Loss: 0.0536
# Epoch 15 | Loss: 0.0533
# Epoch 16 | Loss: 0.0530
# Epoch 17 | Loss: 0.0526
# Epoch 18 | Loss: 0.0523
# Epoch 19 | Loss: 0.0518
# Epoch 20 | Loss: 0.0516
# Epoch 21 | Loss: 0.0514
# Epoch 22 | Loss: 0.0510
# Epoch 23 | Loss: 0.0508
# Epoch 24 | Loss: 0.0505
# Epoch 25 | Loss: 0.0507
# NCE Accuracy at 0.4 noise level: 35.71%
# Training NFL on noise rate 0.4
# Epoch 1 | Loss: 0.7412
# Epoch 2 | Loss: 0.7020
# Epoch 3 | Loss: 0.6837
# Epoch 4 | Loss: 0.6693
# Epoch 5 | Loss: 0.6584
# Epoch 6 | Loss: 0.6466
# Epoch 7 | Loss: 0.6360
# Epoch 8 | Loss: 0.6258
# Epoch 9 | Loss: 0.6161
# Epoch 10 | Loss: 0.6059
# Epoch 11 | Loss: 0.5970
# Epoch 12 | Loss: 0.5879
# Epoch 13 | Loss: 0.5793
# Epoch 14 | Loss: 0.5677
# Epoch 15 | Loss: 0.5590
# Epoch 16 | Loss: 0.5464
# Epoch 17 | Loss: 0.5336
# Epoch 18 | Loss: 0.5199
# Epoch 19 | Loss: 0.5031
# Epoch 20 | Loss: 0.4847
# Epoch 21 | Loss: 0.4652
# Epoch 22 | Loss: 0.4469
# Epoch 23 | Loss: 0.4303
# Epoch 24 | Loss: 0.4168
# Epoch 25 | Loss: 0.4083
# NFL Accuracy at 0.4 noise level: 71.69%
# Training MAE on noise rate 0.4
# Epoch 1 | Loss: 0.1793
# Epoch 2 | Loss: 0.1764
# Epoch 3 | Loss: 0.1746
# Epoch 4 | Loss: 0.1723
# Epoch 5 | Loss: 0.1686
# Epoch 6 | Loss: 0.1651
# Epoch 7 | Loss: 0.1624
# Epoch 8 | Loss: 0.1601
# Epoch 9 | Loss: 0.1584
# Epoch 10 | Loss: 0.1566
# Epoch 11 | Loss: 0.1552
# Epoch 12 | Loss: 0.1541
# Epoch 13 | Loss: 0.1533
# Epoch 14 | Loss: 0.1527
# Epoch 15 | Loss: 0.1519
# Epoch 16 | Loss: 0.1514
# Epoch 17 | Loss: 0.1511
# Epoch 18 | Loss: 0.1507
# Epoch 19 | Loss: 0.1505
# Epoch 20 | Loss: 0.1504
# Epoch 21 | Loss: 0.1500
# Epoch 22 | Loss: 0.1502
# Epoch 23 | Loss: 0.1500
# Epoch 24 | Loss: 0.1498
# Epoch 25 | Loss: 0.1499
# MAE Accuracy at 0.4 noise level: 38.90%
# Training RCE on noise rate 0.4
# Epoch 1 | Loss: 3.3287
# Epoch 2 | Loss: 3.1178
# Epoch 3 | Loss: 3.0561
# Epoch 4 | Loss: 3.0373
# Epoch 5 | Loss: 3.0083
# Epoch 6 | Loss: 2.9943
# Epoch 7 | Loss: 2.9723
# Epoch 8 | Loss: 2.9572
# Epoch 9 | Loss: 2.9504
# Epoch 10 | Loss: 2.9373
# Epoch 11 | Loss: 2.9121
# Epoch 12 | Loss: 2.9018
# Epoch 13 | Loss: 2.8914
# Epoch 14 | Loss: 2.8690
# Epoch 15 | Loss: 2.8465
# Epoch 16 | Loss: 2.8371
# Epoch 17 | Loss: 2.8291
# Epoch 18 | Loss: 2.8121
# Epoch 19 | Loss: 2.7985
# Epoch 20 | Loss: 2.7973
# Epoch 21 | Loss: 2.7893
# Epoch 22 | Loss: 2.7822
# Epoch 23 | Loss: 2.7763
# Epoch 24 | Loss: 2.7736
# Epoch 25 | Loss: 2.7725
# RCE Accuracy at 0.4 noise level: 47.18%
# Training APL_NCE_RCE on noise rate 0.4
# Epoch 1 | Loss: 3.3999
# Epoch 2 | Loss: 3.3848
# Epoch 3 | Loss: 3.3867
# Epoch 4 | Loss: 3.3744
# Epoch 5 | Loss: 3.4056
# Epoch 6 | Loss: 3.4600
# Epoch 7 | Loss: 3.4567
# Epoch 8 | Loss: 3.4273
# Epoch 9 | Loss: 3.4261
# Epoch 10 | Loss: 3.3974
# Epoch 11 | Loss: 3.3638
# Epoch 12 | Loss: 3.3613
# Epoch 13 | Loss: 3.3181
# Epoch 14 | Loss: 3.3096
# Epoch 15 | Loss: 3.2760
# Epoch 16 | Loss: 3.2586
# Epoch 17 | Loss: 3.2520
# Epoch 18 | Loss: 3.2372
# Epoch 19 | Loss: 3.2168
# Epoch 20 | Loss: 3.2023
# Epoch 21 | Loss: 3.1771
# Epoch 22 | Loss: 3.1785
# Epoch 23 | Loss: 3.1594
# Epoch 24 | Loss: 3.1538
# Epoch 25 | Loss: 3.1703
# APL_NCE_RCE Accuracy at 0.4 noise level: 35.07%
# Training APL_NFL_MAE on noise rate 0.4
# Epoch 1 | Loss: 0.9178
# Epoch 2 | Loss: 0.8707
# Epoch 3 | Loss: 0.8510
# Epoch 4 | Loss: 0.8341
# Epoch 5 | Loss: 0.8206
# Epoch 6 | Loss: 0.8080
# Epoch 7 | Loss: 0.7955
# Epoch 8 | Loss: 0.7860
# Epoch 9 | Loss: 0.7764
# Epoch 10 | Loss: 0.7653
# Epoch 11 | Loss: 0.7557
# Epoch 12 | Loss: 0.7484
# Epoch 13 | Loss: 0.7374
# Epoch 14 | Loss: 0.7277
# Epoch 15 | Loss: 0.7184
# Epoch 16 | Loss: 0.7067
# Epoch 17 | Loss: 0.6974
# Epoch 18 | Loss: 0.6841
# Epoch 19 | Loss: 0.6703
# Epoch 20 | Loss: 0.6579
# Epoch 21 | Loss: 0.6445
# Epoch 22 | Loss: 0.6327
# Epoch 23 | Loss: 0.6226
# Epoch 24 | Loss: 0.6127
# Epoch 25 | Loss: 0.6093
# APL_NFL_MAE Accuracy at 0.4 noise level: 74.65%
# Training CE on noise rate 0.6
# Epoch 1 | Loss: 2.2780
# Epoch 2 | Loss: 2.2471
# Epoch 3 | Loss: 2.2322
# Epoch 4 | Loss: 2.2209
# Epoch 5 | Loss: 2.2127
# Epoch 6 | Loss: 2.2056
# Epoch 7 | Loss: 2.1950
# Epoch 8 | Loss: 2.1868
# Epoch 9 | Loss: 2.1777
# Epoch 10 | Loss: 2.1702
# Epoch 11 | Loss: 2.1591
# Epoch 12 | Loss: 2.1521
# Epoch 13 | Loss: 2.1405
# Epoch 14 | Loss: 2.1295
# Epoch 15 | Loss: 2.1210
# Epoch 16 | Loss: 2.1092
# Epoch 17 | Loss: 2.0924
# Epoch 18 | Loss: 2.0792
# Epoch 19 | Loss: 2.0638
# Epoch 20 | Loss: 2.0475
# Epoch 21 | Loss: 2.0285
# Epoch 22 | Loss: 2.0053
# Epoch 23 | Loss: 1.9889
# Epoch 24 | Loss: 1.9756
# Epoch 25 | Loss: 1.9677
# CE Accuracy at 0.6 noise level: 66.40%
# Training FL on noise rate 0.6
# Epoch 1 | Loss: 1.8362
# Epoch 2 | Loss: 1.8022
# Epoch 3 | Loss: 1.7866
# Epoch 4 | Loss: 1.7772
# Epoch 5 | Loss: 1.7652
# Epoch 6 | Loss: 1.7606
# Epoch 7 | Loss: 1.7491
# Epoch 8 | Loss: 1.7423
# Epoch 9 | Loss: 1.7322
# Epoch 10 | Loss: 1.7239
# Epoch 11 | Loss: 1.7174
# Epoch 12 | Loss: 1.7059
# Epoch 13 | Loss: 1.6947
# Epoch 14 | Loss: 1.6843
# Epoch 15 | Loss: 1.6754
# Epoch 16 | Loss: 1.6621
# Epoch 17 | Loss: 1.6513
# Epoch 18 | Loss: 1.6389
# Epoch 19 | Loss: 1.6250
# Epoch 20 | Loss: 1.6083
# Epoch 21 | Loss: 1.5908
# Epoch 22 | Loss: 1.5779
# Epoch 23 | Loss: 1.5624
# Epoch 24 | Loss: 1.5541
# Epoch 25 | Loss: 1.5467
# FL Accuracy at 0.6 noise level: 66.80%
# Training NCE on noise rate 0.6
# Epoch 1 | Loss: 0.0949
# Epoch 2 | Loss: 0.0827
# Epoch 3 | Loss: 0.0790
# Epoch 4 | Loss: 0.0778
# Epoch 5 | Loss: 0.0770
# Epoch 6 | Loss: 0.0766
# Epoch 7 | Loss: 0.0762
# Epoch 8 | Loss: 0.0759
# Epoch 9 | Loss: 0.0754
# Epoch 10 | Loss: 0.0754
# Epoch 11 | Loss: 0.0752
# Epoch 12 | Loss: 0.0750
# Epoch 13 | Loss: 0.0749
# Epoch 14 | Loss: 0.0744
# Epoch 15 | Loss: 0.0743
# Epoch 16 | Loss: 0.0740
# Epoch 17 | Loss: 0.0737
# Epoch 18 | Loss: 0.0734
# Epoch 19 | Loss: 0.0731
# Epoch 20 | Loss: 0.0731
# Epoch 21 | Loss: 0.0728
# Epoch 22 | Loss: 0.0725
# Epoch 23 | Loss: 0.0725
# Epoch 24 | Loss: 0.0725
# Epoch 25 | Loss: 0.0723
# NCE Accuracy at 0.6 noise level: 33.03%
# Training NFL on noise rate 0.6
# Epoch 1 | Loss: 0.7963
# Epoch 2 | Loss: 0.7809
# Epoch 3 | Loss: 0.7736
# Epoch 4 | Loss: 0.7675
# Epoch 5 | Loss: 0.7629
# Epoch 6 | Loss: 0.7581
# Epoch 7 | Loss: 0.7547
# Epoch 8 | Loss: 0.7502
# Epoch 9 | Loss: 0.7451
# Epoch 10 | Loss: 0.7405
# Epoch 11 | Loss: 0.7358
# Epoch 12 | Loss: 0.7325
# Epoch 13 | Loss: 0.7271
# Epoch 14 | Loss: 0.7220
# Epoch 15 | Loss: 0.7157
# Epoch 16 | Loss: 0.7098
# Epoch 17 | Loss: 0.7031
# Epoch 18 | Loss: 0.6939
# Epoch 19 | Loss: 0.6834
# Epoch 20 | Loss: 0.6719
# Epoch 21 | Loss: 0.6574
# Epoch 22 | Loss: 0.6417
# Epoch 23 | Loss: 0.6265
# Epoch 24 | Loss: 0.6144
# Epoch 25 | Loss: 0.6055
# NFL Accuracy at 0.6 noise level: 61.61%
# Training MAE on noise rate 0.6
# Epoch 1 | Loss: 0.1799
# Epoch 2 | Loss: 0.1796
# Epoch 3 | Loss: 0.1790
# Epoch 4 | Loss: 0.1779
# Epoch 5 | Loss: 0.1768
# Epoch 6 | Loss: 0.1755
# Epoch 7 | Loss: 0.1735
# Epoch 8 | Loss: 0.1721
# Epoch 9 | Loss: 0.1712
# Epoch 10 | Loss: 0.1704
# Epoch 11 | Loss: 0.1697
# Epoch 12 | Loss: 0.1693
# Epoch 13 | Loss: 0.1687
# Epoch 14 | Loss: 0.1687
# Epoch 15 | Loss: 0.1682
# Epoch 16 | Loss: 0.1678
# Epoch 17 | Loss: 0.1677
# Epoch 18 | Loss: 0.1677
# Epoch 19 | Loss: 0.1675
# Epoch 20 | Loss: 0.1674
# Epoch 21 | Loss: 0.1673
# Epoch 22 | Loss: 0.1673
# Epoch 23 | Loss: 0.1672
# Epoch 24 | Loss: 0.1672
# Epoch 25 | Loss: 0.1671
# MAE Accuracy at 0.6 noise level: 30.90%
# Training RCE on noise rate 0.6
# Epoch 1 | Loss: 3.5099
# Epoch 2 | Loss: 3.4344
# Epoch 3 | Loss: 3.4183
# Epoch 4 | Loss: 3.4007
# Epoch 5 | Loss: 3.3887
# Epoch 6 | Loss: 3.3785
# Epoch 7 | Loss: 3.3830
# Epoch 8 | Loss: 3.3662
# Epoch 9 | Loss: 3.3657
# Epoch 10 | Loss: 3.3539
# Epoch 11 | Loss: 3.3535
# Epoch 12 | Loss: 3.3577
# Epoch 13 | Loss: 3.3456
# Epoch 14 | Loss: 3.3378
# Epoch 15 | Loss: 3.3315
# Epoch 16 | Loss: 3.3244
# Epoch 17 | Loss: 3.3261
# Epoch 18 | Loss: 3.3233
# Epoch 19 | Loss: 3.3162
# Epoch 20 | Loss: 3.3076
# Epoch 21 | Loss: 3.3078
# Epoch 22 | Loss: 3.3017
# Epoch 23 | Loss: 3.3014
# Epoch 24 | Loss: 3.3057
# Epoch 25 | Loss: 3.3009
# RCE Accuracy at 0.6 noise level: 31.56%
# Training APL_NCE_RCE on noise rate 0.6
# Epoch 1 | Loss: 3.6751
# Epoch 2 | Loss: 3.5962
# Epoch 3 | Loss: 3.5810
# Epoch 4 | Loss: 3.5799
# Epoch 5 | Loss: 3.5828
# Epoch 6 | Loss: 3.5810
# Epoch 7 | Loss: 3.5621
# Epoch 8 | Loss: 3.5545
# Epoch 9 | Loss: 3.5760
# Epoch 10 | Loss: 3.5511
# Epoch 11 | Loss: 3.5306
# Epoch 12 | Loss: 3.5412
# Epoch 13 | Loss: 3.5412
# Epoch 14 | Loss: 3.5371
# Epoch 15 | Loss: 3.5117
# Epoch 16 | Loss: 3.4983
# Epoch 17 | Loss: 3.4854
# Epoch 18 | Loss: 3.4746
# Epoch 19 | Loss: 3.4752
# Epoch 20 | Loss: 3.4635
# Epoch 21 | Loss: 3.4643
# Epoch 22 | Loss: 3.4495
# Epoch 23 | Loss: 3.4489
# Epoch 24 | Loss: 3.4414
# Epoch 25 | Loss: 3.4380
# APL_NCE_RCE Accuracy at 0.6 noise level: 29.16%
# Training APL_NFL_MAE on noise rate 0.6
# Epoch 1 | Loss: 0.9760
# Epoch 2 | Loss: 0.9581
# Epoch 3 | Loss: 0.9497
# Epoch 4 | Loss: 0.9430
# Epoch 5 | Loss: 0.9380
# Epoch 6 | Loss: 0.9340
# Epoch 7 | Loss: 0.9300
# Epoch 8 | Loss: 0.9251
# Epoch 9 | Loss: 0.9211
# Epoch 10 | Loss: 0.9181
# Epoch 11 | Loss: 0.9125
# Epoch 12 | Loss: 0.9078
# Epoch 13 | Loss: 0.9036
# Epoch 14 | Loss: 0.8973
# Epoch 15 | Loss: 0.8922
# Epoch 16 | Loss: 0.8874
# Epoch 17 | Loss: 0.8815
# Epoch 18 | Loss: 0.8757
# Epoch 19 | Loss: 0.8679
# Epoch 20 | Loss: 0.8598
# Epoch 21 | Loss: 0.8530
# Epoch 22 | Loss: 0.8457
# Epoch 23 | Loss: 0.8388
# Epoch 24 | Loss: 0.8345
# Epoch 25 | Loss: 0.8317
# APL_NFL_MAE Accuracy at 0.6 noise level: 65.39%
# Training CE on noise rate 0.8
# Epoch 1 | Loss: 2.3086
# Epoch 2 | Loss: 2.3026
# Epoch 3 | Loss: 2.3010
# Epoch 4 | Loss: 2.3002
# Epoch 5 | Loss: 2.2988
# Epoch 6 | Loss: 2.2983
# Epoch 7 | Loss: 2.2974
# Epoch 8 | Loss: 2.2970
# Epoch 9 | Loss: 2.2960
# Epoch 10 | Loss: 2.2947
# Epoch 11 | Loss: 2.2936
# Epoch 12 | Loss: 2.2932
# Epoch 13 | Loss: 2.2917
# Epoch 14 | Loss: 2.2907
# Epoch 15 | Loss: 2.2890
# Epoch 16 | Loss: 2.2891
# Epoch 17 | Loss: 2.2873
# Epoch 18 | Loss: 2.2857
# Epoch 19 | Loss: 2.2850
# Epoch 20 | Loss: 2.2837
# Epoch 21 | Loss: 2.2816
# Epoch 22 | Loss: 2.2798
# Epoch 23 | Loss: 2.2797
# Epoch 24 | Loss: 2.2785
# Epoch 25 | Loss: 2.2775
# CE Accuracy at 0.8 noise level: 45.03%
# Training FL on noise rate 0.8
# Epoch 1 | Loss: 1.8736
# Epoch 2 | Loss: 1.8657
# Epoch 3 | Loss: 1.8637
# Epoch 4 | Loss: 1.8625
# Epoch 5 | Loss: 1.8618
# Epoch 6 | Loss: 1.8614
# Epoch 7 | Loss: 1.8600
# Epoch 8 | Loss: 1.8589
# Epoch 9 | Loss: 1.8581
# Epoch 10 | Loss: 1.8571
# Epoch 11 | Loss: 1.8564
# Epoch 12 | Loss: 1.8554
# Epoch 13 | Loss: 1.8538
# Epoch 14 | Loss: 1.8530
# Epoch 15 | Loss: 1.8514
# Epoch 16 | Loss: 1.8499
# Epoch 17 | Loss: 1.8486
# Epoch 18 | Loss: 1.8469
# Epoch 19 | Loss: 1.8456
# Epoch 20 | Loss: 1.8437
# Epoch 21 | Loss: 1.8426
# Epoch 22 | Loss: 1.8414
# Epoch 23 | Loss: 1.8402
# Epoch 24 | Loss: 1.8396
# Epoch 25 | Loss: 1.8399
# FL Accuracy at 0.8 noise level: 45.65%
# Training NCE on noise rate 0.8
# Epoch 1 | Loss: 0.0999
# Epoch 2 | Loss: 0.0990
# Epoch 3 | Loss: 0.0973
# Epoch 4 | Loss: 0.0951
# Epoch 5 | Loss: 0.0937
# Epoch 6 | Loss: 0.0931
# Epoch 7 | Loss: 0.0929
# Epoch 8 | Loss: 0.0926
# Epoch 9 | Loss: 0.0921
# Epoch 10 | Loss: 0.0921
# Epoch 11 | Loss: 0.0921
# Epoch 12 | Loss: 0.0919
# Epoch 13 | Loss: 0.0917
# Epoch 14 | Loss: 0.0913
# Epoch 15 | Loss: 0.0913
# Epoch 16 | Loss: 0.0912
# Epoch 17 | Loss: 0.0910
# Epoch 18 | Loss: 0.0908
# Epoch 19 | Loss: 0.0908
# Epoch 20 | Loss: 0.0906
# Epoch 21 | Loss: 0.0903
# Epoch 22 | Loss: 0.0901
# Epoch 23 | Loss: 0.0900
# Epoch 24 | Loss: 0.0897
# Epoch 25 | Loss: 0.0898
# NCE Accuracy at 0.8 noise level: 22.75%
# Training NFL on noise rate 0.8
# Epoch 1 | Loss: 0.8134
# Epoch 2 | Loss: 0.8097
# Epoch 3 | Loss: 0.8089
# Epoch 4 | Loss: 0.8084
# Epoch 5 | Loss: 0.8079
# Epoch 6 | Loss: 0.8076
# Epoch 7 | Loss: 0.8071
# Epoch 8 | Loss: 0.8064
# Epoch 9 | Loss: 0.8061
# Epoch 10 | Loss: 0.8057
# Epoch 11 | Loss: 0.8055
# Epoch 12 | Loss: 0.8044
# Epoch 13 | Loss: 0.8042
# Epoch 14 | Loss: 0.8036
# Epoch 15 | Loss: 0.8028
# Epoch 16 | Loss: 0.8020
# Epoch 17 | Loss: 0.8013
# Epoch 18 | Loss: 0.8003
# Epoch 19 | Loss: 0.7989
# Epoch 20 | Loss: 0.7983
# Epoch 21 | Loss: 0.7964
# Epoch 22 | Loss: 0.7950
# Epoch 23 | Loss: 0.7935
# Epoch 24 | Loss: 0.7924
# Epoch 25 | Loss: 0.7913
# NFL Accuracy at 0.8 noise level: 39.58%
# Training MAE on noise rate 0.8
# Epoch 1 | Loss: 0.1800
# Epoch 2 | Loss: 0.1800
# Epoch 3 | Loss: 0.1799
# Epoch 4 | Loss: 0.1798
# Epoch 5 | Loss: 0.1797
# Epoch 6 | Loss: 0.1794
# Epoch 7 | Loss: 0.1791
# Epoch 8 | Loss: 0.1789
# Epoch 9 | Loss: 0.1789
# Epoch 10 | Loss: 0.1789
# Epoch 11 | Loss: 0.1788
# Epoch 12 | Loss: 0.1787
# Epoch 13 | Loss: 0.1787
# Epoch 14 | Loss: 0.1787
# Epoch 15 | Loss: 0.1787
# Epoch 16 | Loss: 0.1786
# Epoch 17 | Loss: 0.1786
# Epoch 18 | Loss: 0.1786
# Epoch 19 | Loss: 0.1786
# Epoch 20 | Loss: 0.1785
# Epoch 21 | Loss: 0.1785
# Epoch 22 | Loss: 0.1785
# Epoch 23 | Loss: 0.1785
# Epoch 24 | Loss: 0.1786
# Epoch 25 | Loss: 0.1785
# MAE Accuracy at 0.8 noise level: 15.98%
# Training RCE on noise rate 0.8
# Epoch 1 | Loss: 3.5833
# Epoch 2 | Loss: 3.5608
# Epoch 3 | Loss: 3.5560
# Epoch 4 | Loss: 3.5612
# Epoch 5 | Loss: 3.5609
# Epoch 6 | Loss: 3.5575
# Epoch 7 | Loss: 3.5568
# Epoch 8 | Loss: 3.5638
# Epoch 9 | Loss: 3.5616
# Epoch 10 | Loss: 3.5563
# Epoch 11 | Loss: 3.5521
# Epoch 12 | Loss: 3.5536
# Epoch 13 | Loss: 3.5549
# Epoch 14 | Loss: 3.5590
# Epoch 15 | Loss: 3.5549
# Epoch 16 | Loss: 3.5536
# Epoch 17 | Loss: 3.5480
# Epoch 18 | Loss: 3.5442
# Epoch 19 | Loss: 3.5414
# Epoch 20 | Loss: 3.5405
# Epoch 21 | Loss: 3.5371
# Epoch 22 | Loss: 3.5352
# Epoch 23 | Loss: 3.5364
# Epoch 24 | Loss: 3.5320
# Epoch 25 | Loss: 3.5238
# RCE Accuracy at 0.8 noise level: 21.03%
# Training APL_NCE_RCE on noise rate 0.8
# Epoch 1 | Loss: 3.6873
# Epoch 2 | Loss: 3.6759
# Epoch 3 | Loss: 3.6835
# Epoch 4 | Loss: 3.6692
# Epoch 5 | Loss: 3.6696
# Epoch 6 | Loss: 3.6627
# Epoch 7 | Loss: 3.6597
# Epoch 8 | Loss: 3.6491
# Epoch 9 | Loss: 3.6537
# Epoch 10 | Loss: 3.6561
# Epoch 11 | Loss: 3.6639
# Epoch 12 | Loss: 3.6616
# Epoch 13 | Loss: 3.6648
# Epoch 14 | Loss: 3.6713
# Epoch 15 | Loss: 3.6587
# Epoch 16 | Loss: 3.6558
# Epoch 17 | Loss: 3.6510
# Epoch 18 | Loss: 3.6562
# Epoch 19 | Loss: 3.6534
# Epoch 20 | Loss: 3.6593
# Epoch 21 | Loss: 3.6516
# Epoch 22 | Loss: 3.6535
# Epoch 23 | Loss: 3.6509
# Epoch 24 | Loss: 3.6522
# Epoch 25 | Loss: 3.6525
# APL_NCE_RCE Accuracy at 0.8 noise level: 16.92%
# Training APL_NFL_MAE on noise rate 0.8
# Epoch 1 | Loss: 0.9932
# Epoch 2 | Loss: 0.9897
# Epoch 3 | Loss: 0.9889
# Epoch 4 | Loss: 0.9881
# Epoch 5 | Loss: 0.9878
# Epoch 6 | Loss: 0.9871
# Epoch 7 | Loss: 0.9866
# Epoch 8 | Loss: 0.9863
# Epoch 9 | Loss: 0.9858
# Epoch 10 | Loss: 0.9851
# Epoch 11 | Loss: 0.9847
# Epoch 12 | Loss: 0.9840
# Epoch 13 | Loss: 0.9838
# Epoch 14 | Loss: 0.9832
# Epoch 15 | Loss: 0.9825
# Epoch 16 | Loss: 0.9822
# Epoch 17 | Loss: 0.9815
# Epoch 18 | Loss: 0.9811
# Epoch 19 | Loss: 0.9807
# Epoch 20 | Loss: 0.9795
# Epoch 21 | Loss: 0.9792
# Epoch 22 | Loss: 0.9783
# Epoch 23 | Loss: 0.9783
# Epoch 24 | Loss: 0.9778
# Epoch 25 | Loss: 0.9778
# APL_NFL_MAE Accuracy at 0.8 noise level: 45.55%
# [Asymmetric] Training CE at noise rate 0.1
# Epoch 1 | Loss: 1.6040
# Epoch 2 | Loss: 1.2571
# Epoch 3 | Loss: 1.1083
# Epoch 4 | Loss: 1.0168
# Epoch 5 | Loss: 0.9367
# Epoch 6 | Loss: 0.8741
# Epoch 7 | Loss: 0.8192
# Epoch 8 | Loss: 0.7699
# Epoch 9 | Loss: 0.7279
# Epoch 10 | Loss: 0.6797
# Epoch 11 | Loss: 0.6430
# Epoch 12 | Loss: 0.6023
# Epoch 13 | Loss: 0.5657
# Epoch 14 | Loss: 0.5294
# Epoch 15 | Loss: 0.4931
# Epoch 16 | Loss: 0.4579
# Epoch 17 | Loss: 0.4248
# Epoch 18 | Loss: 0.3911
# Epoch 19 | Loss: 0.3611
# Epoch 20 | Loss: 0.3374
# Epoch 21 | Loss: 0.3147
# Epoch 22 | Loss: 0.2940
# Epoch 23 | Loss: 0.2850
# Epoch 24 | Loss: 0.2791
# Epoch 25 | Loss: 0.2732
# [Asymmetric] CE Accuracy at 0.1 noise level: 82.82%
# [Asymmetric] Training FL at noise rate 0.1
# Epoch 1 | Loss: 1.1077
# Epoch 2 | Loss: 0.8152
# Epoch 3 | Loss: 0.7112
# Epoch 4 | Loss: 0.6290
# Epoch 5 | Loss: 0.5708
# Epoch 6 | Loss: 0.5249
# Epoch 7 | Loss: 0.4867
# Epoch 8 | Loss: 0.4482
# Epoch 9 | Loss: 0.4168
# Epoch 10 | Loss: 0.3780
# Epoch 11 | Loss: 0.3522
# Epoch 12 | Loss: 0.3229
# Epoch 13 | Loss: 0.2925
# Epoch 14 | Loss: 0.2690
# Epoch 15 | Loss: 0.2461
# Epoch 16 | Loss: 0.2220
# Epoch 17 | Loss: 0.2035
# Epoch 18 | Loss: 0.1813
# Epoch 19 | Loss: 0.1645
# Epoch 20 | Loss: 0.1513
# Epoch 21 | Loss: 0.1374
# Epoch 22 | Loss: 0.1286
# Epoch 23 | Loss: 0.1228
# Epoch 24 | Loss: 0.1209
# Epoch 25 | Loss: 0.1184
# [Asymmetric] FL Accuracy at 0.1 noise level: 82.10%
# [Asymmetric] Training NCE at noise rate 0.1
# Epoch 1 | Loss: 0.0542
# Epoch 2 | Loss: 0.0269
# Epoch 3 | Loss: 0.0220
# Epoch 4 | Loss: 0.0194
# Epoch 5 | Loss: 0.0179
# Epoch 6 | Loss: 0.0166
# Epoch 7 | Loss: 0.0156
# Epoch 8 | Loss: 0.0153
# Epoch 9 | Loss: 0.0144
# Epoch 10 | Loss: 0.0141
# Epoch 11 | Loss: 0.0137
# Epoch 12 | Loss: 0.0131
# Epoch 13 | Loss: 0.0126
# Epoch 14 | Loss: 0.0123
# Epoch 15 | Loss: 0.0119
# Epoch 16 | Loss: 0.0114
# Epoch 17 | Loss: 0.0112
# Epoch 18 | Loss: 0.0107
# Epoch 19 | Loss: 0.0103
# Epoch 20 | Loss: 0.0101
# Epoch 21 | Loss: 0.0097
# Epoch 22 | Loss: 0.0095
# Epoch 23 | Loss: 0.0092
# Epoch 24 | Loss: 0.0091
# Epoch 25 | Loss: 0.0092
# [Asymmetric] NCE Accuracy at 0.1 noise level: 37.15%
# [Asymmetric] Training NFL at noise rate 0.1
# Epoch 1 | Loss: 0.4832
# Epoch 2 | Loss: 0.3548
# Epoch 3 | Loss: 0.3064
# Epoch 4 | Loss: 0.2721
# Epoch 5 | Loss: 0.2449
# Epoch 6 | Loss: 0.2247
# Epoch 7 | Loss: 0.2078
# Epoch 8 | Loss: 0.1928
# Epoch 9 | Loss: 0.1779
# Epoch 10 | Loss: 0.1650
# Epoch 11 | Loss: 0.1526
# Epoch 12 | Loss: 0.1410
# Epoch 13 | Loss: 0.1279
# Epoch 14 | Loss: 0.1164
# Epoch 15 | Loss: 0.1068
# Epoch 16 | Loss: 0.0948
# Epoch 17 | Loss: 0.0839
# Epoch 18 | Loss: 0.0751
# Epoch 19 | Loss: 0.0667
# Epoch 20 | Loss: 0.0598
# Epoch 21 | Loss: 0.0550
# Epoch 22 | Loss: 0.0517
# Epoch 23 | Loss: 0.0488
# Epoch 24 | Loss: 0.0466
# Epoch 25 | Loss: 0.0461
# [Asymmetric] NFL Accuracy at 0.1 noise level: 82.33%
# [Asymmetric] Training MAE at noise rate 0.1
# Epoch 1 | Loss: 0.1772
# Epoch 2 | Loss: 0.1692
# Epoch 3 | Loss: 0.1531
# Epoch 4 | Loss: 0.1431
# Epoch 5 | Loss: 0.1378
# Epoch 6 | Loss: 0.1349
# Epoch 7 | Loss: 0.1330
# Epoch 8 | Loss: 0.1316
# Epoch 9 | Loss: 0.1300
# Epoch 10 | Loss: 0.1281
# Epoch 11 | Loss: 0.1256
# Epoch 12 | Loss: 0.1233
# Epoch 13 | Loss: 0.1215
# Epoch 14 | Loss: 0.1204
# Epoch 15 | Loss: 0.1193
# Epoch 16 | Loss: 0.1187
# Epoch 17 | Loss: 0.1178
# Epoch 18 | Loss: 0.1173
# Epoch 19 | Loss: 0.1169
# Epoch 20 | Loss: 0.1164
# Epoch 21 | Loss: 0.1161
# Epoch 22 | Loss: 0.1160
# Epoch 23 | Loss: 0.1161
# Epoch 24 | Loss: 0.1160
# Epoch 25 | Loss: 0.1157
# [Asymmetric] MAE Accuracy at 0.1 noise level: 43.03%
# [Asymmetric] Training RCE at noise rate 0.1
# Epoch 1 | Loss: 3.0211
# Epoch 2 | Loss: 2.7524
# Epoch 3 | Loss: 2.5920
# Epoch 4 | Loss: 2.5450
# Epoch 5 | Loss: 2.5029
# Epoch 6 | Loss: 2.4813
# Epoch 7 | Loss: 2.4713
# Epoch 8 | Loss: 2.4433
# Epoch 9 | Loss: 2.3917
# Epoch 10 | Loss: 2.3776
# Epoch 11 | Loss: 2.3531
# Epoch 12 | Loss: 2.3361
# Epoch 13 | Loss: 2.3199
# Epoch 14 | Loss: 2.2913
# Epoch 15 | Loss: 2.2675
# Epoch 16 | Loss: 2.2450
# Epoch 17 | Loss: 2.2218
# Epoch 18 | Loss: 2.2017
# Epoch 19 | Loss: 2.1896
# Epoch 20 | Loss: 2.1739
# Epoch 21 | Loss: 2.1637
# Epoch 22 | Loss: 2.1603
# Epoch 23 | Loss: 2.1514
# Epoch 24 | Loss: 2.1470
# Epoch 25 | Loss: 2.1424
# [Asymmetric] RCE Accuracy at 0.1 noise level: 46.77%
# [Asymmetric] Training APL_NCE_RCE at noise rate 0.1
# Epoch 1 | Loss: 3.0254
# Epoch 2 | Loss: 2.9787
# Epoch 3 | Loss: 2.9873
# Epoch 4 | Loss: 3.0029
# Epoch 5 | Loss: 2.9817
# Epoch 6 | Loss: 3.0834
# Epoch 7 | Loss: 3.1545
# Epoch 8 | Loss: 2.9652
# Epoch 9 | Loss: 2.9123
# Epoch 10 | Loss: 2.9501
# Epoch 11 | Loss: 2.9344
# Epoch 12 | Loss: 2.8538
# Epoch 13 | Loss: 2.7921
# Epoch 14 | Loss: 2.7733
# Epoch 15 | Loss: 2.7854
# Epoch 16 | Loss: 2.7317
# Epoch 17 | Loss: 2.6848
# Epoch 18 | Loss: 2.6474
# Epoch 19 | Loss: 2.6173
# Epoch 20 | Loss: 2.5951
# Epoch 21 | Loss: 2.5724
# Epoch 22 | Loss: 2.5264
# Epoch 23 | Loss: 2.5113
# Epoch 24 | Loss: 2.5113
# Epoch 25 | Loss: 2.4942
# [Asymmetric] APL_NCE_RCE Accuracy at 0.1 noise level: 40.91%
# [Asymmetric] Training APL_NFL_MAE at noise rate 0.1
# Epoch 1 | Loss: 0.6306
# Epoch 2 | Loss: 0.4784
# Epoch 3 | Loss: 0.4194
# Epoch 4 | Loss: 0.3803
# Epoch 5 | Loss: 0.3481
# Epoch 6 | Loss: 0.3244
# Epoch 7 | Loss: 0.3060
# Epoch 8 | Loss: 0.2845
# Epoch 9 | Loss: 0.2697
# Epoch 10 | Loss: 0.2538
# Epoch 11 | Loss: 0.2394
# Epoch 12 | Loss: 0.2261
# Epoch 13 | Loss: 0.2120
# Epoch 14 | Loss: 0.1971
# Epoch 15 | Loss: 0.1843
# Epoch 16 | Loss: 0.1730
# Epoch 17 | Loss: 0.1619
# Epoch 18 | Loss: 0.1507
# Epoch 19 | Loss: 0.1410
# Epoch 20 | Loss: 0.1311
# Epoch 21 | Loss: 0.1248
# Epoch 22 | Loss: 0.1187
# Epoch 23 | Loss: 0.1136
# Epoch 24 | Loss: 0.1116
# Epoch 25 | Loss: 0.1092
# [Asymmetric] APL_NFL_MAE Accuracy at 0.1 noise level: 82.27%
# [Asymmetric] Training CE at noise rate 0.25
# Epoch 1 | Loss: 1.6248
# Epoch 2 | Loss: 1.3026
# Epoch 3 | Loss: 1.1729
# Epoch 4 | Loss: 1.0845
# Epoch 5 | Loss: 1.0176
# Epoch 6 | Loss: 0.9592
# Epoch 7 | Loss: 0.9096
# Epoch 8 | Loss: 0.8602
# Epoch 9 | Loss: 0.8234
# Epoch 10 | Loss: 0.7825
# Epoch 11 | Loss: 0.7404
# Epoch 12 | Loss: 0.7081
# Epoch 13 | Loss: 0.6729
# Epoch 14 | Loss: 0.6334
# Epoch 15 | Loss: 0.6065
# Epoch 16 | Loss: 0.5699
# Epoch 17 | Loss: 0.5381
# Epoch 18 | Loss: 0.5108
# Epoch 19 | Loss: 0.4831
# Epoch 20 | Loss: 0.4645
# Epoch 21 | Loss: 0.4439
# Epoch 22 | Loss: 0.4296
# Epoch 23 | Loss: 0.4187
# Epoch 24 | Loss: 0.4125
# Epoch 25 | Loss: 0.4092
# [Asymmetric] CE Accuracy at 0.25 noise level: 80.91%
# [Asymmetric] Training FL at noise rate 0.25
# Epoch 1 | Loss: 1.1386
# Epoch 2 | Loss: 0.8496
# Epoch 3 | Loss: 0.7415
# Epoch 4 | Loss: 0.6687
# Epoch 5 | Loss: 0.6090
# Epoch 6 | Loss: 0.5608
# Epoch 7 | Loss: 0.5221
# Epoch 8 | Loss: 0.4840
# Epoch 9 | Loss: 0.4503
# Epoch 10 | Loss: 0.4143
# Epoch 11 | Loss: 0.3875
# Epoch 12 | Loss: 0.3619
# Epoch 13 | Loss: 0.3331
# Epoch 14 | Loss: 0.3018
# Epoch 15 | Loss: 0.2807
# Epoch 16 | Loss: 0.2601
# Epoch 17 | Loss: 0.2324
# Epoch 18 | Loss: 0.2135
# Epoch 19 | Loss: 0.1974
# Epoch 20 | Loss: 0.1809
# Epoch 21 | Loss: 0.1713
# Epoch 22 | Loss: 0.1593
# Epoch 23 | Loss: 0.1552
# Epoch 24 | Loss: 0.1484
# Epoch 25 | Loss: 0.1479
# [Asymmetric] FL Accuracy at 0.25 noise level: 79.86%
# [Asymmetric] Training NCE at noise rate 0.25
# Epoch 1 | Loss: 0.0555
# Epoch 2 | Loss: 0.0260
# Epoch 3 | Loss: 0.0206
# Epoch 4 | Loss: 0.0183
# Epoch 5 | Loss: 0.0168
# Epoch 6 | Loss: 0.0159
# Epoch 7 | Loss: 0.0151
# Epoch 8 | Loss: 0.0146
# Epoch 9 | Loss: 0.0140
# Epoch 10 | Loss: 0.0135
# Epoch 11 | Loss: 0.0131
# Epoch 12 | Loss: 0.0128
# Epoch 13 | Loss: 0.0122
# Epoch 14 | Loss: 0.0120
# Epoch 15 | Loss: 0.0117
# Epoch 16 | Loss: 0.0112
# Epoch 17 | Loss: 0.0107
# Epoch 18 | Loss: 0.0106
# Epoch 19 | Loss: 0.0101
# Epoch 20 | Loss: 0.0097
# Epoch 21 | Loss: 0.0096
# Epoch 22 | Loss: 0.0092
# Epoch 23 | Loss: 0.0091
# Epoch 24 | Loss: 0.0090
# Epoch 25 | Loss: 0.0089
# [Asymmetric] NCE Accuracy at 0.25 noise level: 36.53%
# [Asymmetric] Training NFL at noise rate 0.25
# Epoch 1 | Loss: 0.4921
# Epoch 2 | Loss: 0.3673
# Epoch 3 | Loss: 0.3199
# Epoch 4 | Loss: 0.2877
# Epoch 5 | Loss: 0.2634
# Epoch 6 | Loss: 0.2422
# Epoch 7 | Loss: 0.2261
# Epoch 8 | Loss: 0.2081
# Epoch 9 | Loss: 0.1964
# Epoch 10 | Loss: 0.1810
# Epoch 11 | Loss: 0.1693
# Epoch 12 | Loss: 0.1598
# Epoch 13 | Loss: 0.1459
# Epoch 14 | Loss: 0.1333
# Epoch 15 | Loss: 0.1220
# Epoch 16 | Loss: 0.1107
# Epoch 17 | Loss: 0.1002
# Epoch 18 | Loss: 0.0915
# Epoch 19 | Loss: 0.0824
# Epoch 20 | Loss: 0.0757
# Epoch 21 | Loss: 0.0692
# Epoch 22 | Loss: 0.0660
# Epoch 23 | Loss: 0.0626
# Epoch 24 | Loss: 0.0608
# Epoch 25 | Loss: 0.0602
# [Asymmetric] NFL Accuracy at 0.25 noise level: 79.58%
# [Asymmetric] Training MAE at noise rate 0.25
# Epoch 1 | Loss: 0.1747
# Epoch 2 | Loss: 0.1625
# Epoch 3 | Loss: 0.1591
# Epoch 4 | Loss: 0.1577
# Epoch 5 | Loss: 0.1567
# Epoch 6 | Loss: 0.1545
# Epoch 7 | Loss: 0.1490
# Epoch 8 | Loss: 0.1457
# Epoch 9 | Loss: 0.1441
# Epoch 10 | Loss: 0.1429
# Epoch 11 | Loss: 0.1416
# Epoch 12 | Loss: 0.1386
# Epoch 13 | Loss: 0.1348
# Epoch 14 | Loss: 0.1323
# Epoch 15 | Loss: 0.1307
# Epoch 16 | Loss: 0.1295
# Epoch 17 | Loss: 0.1288
# Epoch 18 | Loss: 0.1282
# Epoch 19 | Loss: 0.1275
# Epoch 20 | Loss: 0.1272
# Epoch 21 | Loss: 0.1269
# Epoch 22 | Loss: 0.1265
# Epoch 23 | Loss: 0.1265
# Epoch 24 | Loss: 0.1264
# Epoch 25 | Loss: 0.1265
# [Asymmetric] MAE Accuracy at 0.25 noise level: 35.65%
# [Asymmetric] Training RCE at noise rate 0.25
# Epoch 1 | Loss: 3.0843
# Epoch 2 | Loss: 2.9271
# Epoch 3 | Loss: 2.8931
# Epoch 4 | Loss: 2.6552
# Epoch 5 | Loss: 2.5412
# Epoch 6 | Loss: 2.4991
# Epoch 7 | Loss: 2.4712
# Epoch 8 | Loss: 2.4497
# Epoch 9 | Loss: 2.4181
# Epoch 10 | Loss: 2.4085
# Epoch 11 | Loss: 2.3892
# Epoch 12 | Loss: 2.3686
# Epoch 13 | Loss: 2.3561
# Epoch 14 | Loss: 2.3244
# Epoch 15 | Loss: 2.3070
# Epoch 16 | Loss: 2.2855
# Epoch 17 | Loss: 2.2768
# Epoch 18 | Loss: 2.2595
# Epoch 19 | Loss: 2.2454
# Epoch 20 | Loss: 2.2356
# Epoch 21 | Loss: 2.2224
# Epoch 22 | Loss: 2.2111
# Epoch 23 | Loss: 2.2114
# Epoch 24 | Loss: 2.2089
# Epoch 25 | Loss: 2.2026
# [Asymmetric] RCE Accuracy at 0.25 noise level: 42.25%
# [Asymmetric] Training APL_NCE_RCE at noise rate 0.25
# Epoch 1 | Loss: 3.0991
# Epoch 2 | Loss: 2.9668
# Epoch 3 | Loss: 3.0903
# Epoch 4 | Loss: 3.1058
# Epoch 5 | Loss: 3.1191
# Epoch 6 | Loss: 3.1208
# Epoch 7 | Loss: 3.0824
# Epoch 8 | Loss: 3.1257
# Epoch 9 | Loss: 3.1229
# Epoch 10 | Loss: 3.0840
# Epoch 11 | Loss: 3.0962
# Epoch 12 | Loss: 3.0173
# Epoch 13 | Loss: 2.9813
# Epoch 14 | Loss: 2.9318
# Epoch 15 | Loss: 2.9118
# Epoch 16 | Loss: 2.8842
# Epoch 17 | Loss: 2.8318
# Epoch 18 | Loss: 2.7969
# Epoch 19 | Loss: 2.7834
# Epoch 20 | Loss: 2.7681
# Epoch 21 | Loss: 2.7701
# Epoch 22 | Loss: 2.7612
# Epoch 23 | Loss: 2.7455
# Epoch 24 | Loss: 2.7426
# Epoch 25 | Loss: 2.7330
# [Asymmetric] APL_NCE_RCE Accuracy at 0.25 noise level: 32.75%
# [Asymmetric] Training APL_NFL_MAE at noise rate 0.25
# Epoch 1 | Loss: 0.6449
# Epoch 2 | Loss: 0.4943
# Epoch 3 | Loss: 0.4374
# Epoch 4 | Loss: 0.4005
# Epoch 5 | Loss: 0.3716
# Epoch 6 | Loss: 0.3495
# Epoch 7 | Loss: 0.3304
# Epoch 8 | Loss: 0.3128
# Epoch 9 | Loss: 0.2949
# Epoch 10 | Loss: 0.2811
# Epoch 11 | Loss: 0.2657
# Epoch 12 | Loss: 0.2520
# Epoch 13 | Loss: 0.2367
# Epoch 14 | Loss: 0.2260
# Epoch 15 | Loss: 0.2121
# Epoch 16 | Loss: 0.2003
# Epoch 17 | Loss: 0.1905
# Epoch 18 | Loss: 0.1780
# Epoch 19 | Loss: 0.1676
# Epoch 20 | Loss: 0.1589
# Epoch 21 | Loss: 0.1511
# Epoch 22 | Loss: 0.1459
# Epoch 23 | Loss: 0.1416
# Epoch 24 | Loss: 0.1383
# Epoch 25 | Loss: 0.1373
# [Asymmetric] APL_NFL_MAE Accuracy at 0.25 noise level: 80.29%
# [Asymmetric] Training CE at noise rate 0.4
# Epoch 1 | Loss: 1.6162
# Epoch 2 | Loss: 1.3180
# Epoch 3 | Loss: 1.1889
# Epoch 4 | Loss: 1.1057
# Epoch 5 | Loss: 1.0392
# Epoch 6 | Loss: 0.9873
# Epoch 7 | Loss: 0.9412
# Epoch 8 | Loss: 0.8988
# Epoch 9 | Loss: 0.8596
# Epoch 10 | Loss: 0.8173
# Epoch 11 | Loss: 0.7801
# Epoch 12 | Loss: 0.7512
# Epoch 13 | Loss: 0.7130
# Epoch 14 | Loss: 0.6804
# Epoch 15 | Loss: 0.6547
# Epoch 16 | Loss: 0.6232
# Epoch 17 | Loss: 0.5912
# Epoch 18 | Loss: 0.5663
# Epoch 19 | Loss: 0.5396
# Epoch 20 | Loss: 0.5207
# Epoch 21 | Loss: 0.5040
# Epoch 22 | Loss: 0.4874
# Epoch 23 | Loss: 0.4795
# Epoch 24 | Loss: 0.4737
# Epoch 25 | Loss: 0.4714
# [Asymmetric] CE Accuracy at 0.4 noise level: 78.01%
# [Asymmetric] Training FL at noise rate 0.4
# Epoch 1 | Loss: 1.1330
# Epoch 2 | Loss: 0.8565
# Epoch 3 | Loss: 0.7438
# Epoch 4 | Loss: 0.6669
# Epoch 5 | Loss: 0.6169
# Epoch 6 | Loss: 0.5666
# Epoch 7 | Loss: 0.5215
# Epoch 8 | Loss: 0.4885
# Epoch 9 | Loss: 0.4596
# Epoch 10 | Loss: 0.4276
# Epoch 11 | Loss: 0.4003
# Epoch 12 | Loss: 0.3723
# Epoch 13 | Loss: 0.3446
# Epoch 14 | Loss: 0.3125
# Epoch 15 | Loss: 0.2856
# Epoch 16 | Loss: 0.2642
# Epoch 17 | Loss: 0.2439
# Epoch 18 | Loss: 0.2277
# Epoch 19 | Loss: 0.2099
# Epoch 20 | Loss: 0.1915
# Epoch 21 | Loss: 0.1787
# Epoch 22 | Loss: 0.1730
# Epoch 23 | Loss: 0.1621
# Epoch 24 | Loss: 0.1587
# Epoch 25 | Loss: 0.1590
# [Asymmetric] FL Accuracy at 0.4 noise level: 75.15%
# [Asymmetric] Training NCE at noise rate 0.4
# Epoch 1 | Loss: 0.0565
# Epoch 2 | Loss: 0.0265
# Epoch 3 | Loss: 0.0206
# Epoch 4 | Loss: 0.0183
# Epoch 5 | Loss: 0.0165
# Epoch 6 | Loss: 0.0159
# Epoch 7 | Loss: 0.0149
# Epoch 8 | Loss: 0.0142
# Epoch 9 | Loss: 0.0139
# Epoch 10 | Loss: 0.0135
# Epoch 11 | Loss: 0.0127
# Epoch 12 | Loss: 0.0124
# Epoch 13 | Loss: 0.0120
# Epoch 14 | Loss: 0.0116
# Epoch 15 | Loss: 0.0112
# Epoch 16 | Loss: 0.0109
# Epoch 17 | Loss: 0.0104
# Epoch 18 | Loss: 0.0100
# Epoch 19 | Loss: 0.0098
# Epoch 20 | Loss: 0.0094
# Epoch 21 | Loss: 0.0091
# Epoch 22 | Loss: 0.0091
# Epoch 23 | Loss: 0.0087
# Epoch 24 | Loss: 0.0086
# Epoch 25 | Loss: 0.0087
# [Asymmetric] NCE Accuracy at 0.4 noise level: 34.80%
# [Asymmetric] Training NFL at noise rate 0.4
# Epoch 1 | Loss: 0.4870
# Epoch 2 | Loss: 0.3686
# Epoch 3 | Loss: 0.3197
# Epoch 4 | Loss: 0.2876
# Epoch 5 | Loss: 0.2644
# Epoch 6 | Loss: 0.2441
# Epoch 7 | Loss: 0.2274
# Epoch 8 | Loss: 0.2144
# Epoch 9 | Loss: 0.1996
# Epoch 10 | Loss: 0.1856
# Epoch 11 | Loss: 0.1724
# Epoch 12 | Loss: 0.1608
# Epoch 13 | Loss: 0.1492
# Epoch 14 | Loss: 0.1362
# Epoch 15 | Loss: 0.1256
# Epoch 16 | Loss: 0.1153
# Epoch 17 | Loss: 0.1036
# Epoch 18 | Loss: 0.0950
# Epoch 19 | Loss: 0.0866
# Epoch 20 | Loss: 0.0789
# Epoch 21 | Loss: 0.0739
# Epoch 22 | Loss: 0.0694
# Epoch 23 | Loss: 0.0667
# Epoch 24 | Loss: 0.0643
# Epoch 25 | Loss: 0.0636
# [Asymmetric] NFL Accuracy at 0.4 noise level: 72.86%
# [Asymmetric] Training MAE at noise rate 0.4
# Epoch 1 | Loss: 0.1735
# Epoch 2 | Loss: 0.1584
# Epoch 3 | Loss: 0.1555
# Epoch 4 | Loss: 0.1542
# Epoch 5 | Loss: 0.1537
# Epoch 6 | Loss: 0.1531
# Epoch 7 | Loss: 0.1529
# Epoch 8 | Loss: 0.1524
# Epoch 9 | Loss: 0.1518
# Epoch 10 | Loss: 0.1503
# Epoch 11 | Loss: 0.1461
# Epoch 12 | Loss: 0.1428
# Epoch 13 | Loss: 0.1412
# Epoch 14 | Loss: 0.1399
# Epoch 15 | Loss: 0.1392
# Epoch 16 | Loss: 0.1387
# Epoch 17 | Loss: 0.1382
# Epoch 18 | Loss: 0.1376
# Epoch 19 | Loss: 0.1373
# Epoch 20 | Loss: 0.1373
# Epoch 21 | Loss: 0.1368
# Epoch 22 | Loss: 0.1368
# Epoch 23 | Loss: 0.1368
# Epoch 24 | Loss: 0.1365
# Epoch 25 | Loss: 0.1367
# [Asymmetric] MAE Accuracy at 0.4 noise level: 26.71%
# [Asymmetric] Training RCE at noise rate 0.4
# Epoch 1 | Loss: 3.1200
# Epoch 2 | Loss: 2.8834
# Epoch 3 | Loss: 2.8448
# Epoch 4 | Loss: 2.8374
# Epoch 5 | Loss: 2.8216
# Epoch 6 | Loss: 2.8093
# Epoch 7 | Loss: 2.7734
# Epoch 8 | Loss: 2.6710
# Epoch 9 | Loss: 2.6220
# Epoch 10 | Loss: 2.5649
# Epoch 11 | Loss: 2.5289
# Epoch 12 | Loss: 2.5061
# Epoch 13 | Loss: 2.4663
# Epoch 14 | Loss: 2.4207
# Epoch 15 | Loss: 2.3458
# Epoch 16 | Loss: 2.3063
# Epoch 17 | Loss: 2.2778
# Epoch 18 | Loss: 2.2622
# Epoch 19 | Loss: 2.2322
# Epoch 20 | Loss: 2.2215
# Epoch 21 | Loss: 2.2078
# Epoch 22 | Loss: 2.1958
# Epoch 23 | Loss: 2.1853
# Epoch 24 | Loss: 2.1813
# Epoch 25 | Loss: 2.1880
# [Asymmetric] RCE Accuracy at 0.4 noise level: 41.13%
# [Asymmetric] Training APL_NCE_RCE at noise rate 0.4
# Epoch 1 | Loss: 3.0918
# Epoch 2 | Loss: 2.9376
# Epoch 3 | Loss: 3.0330
# Epoch 4 | Loss: 3.0582
# Epoch 5 | Loss: 2.9723
# Epoch 6 | Loss: 3.0634
# Epoch 7 | Loss: 3.0919
# Epoch 8 | Loss: 3.0837
# Epoch 9 | Loss: 3.1208
# Epoch 10 | Loss: 3.0586
# Epoch 11 | Loss: 3.0465
# Epoch 12 | Loss: 3.0402
# Epoch 13 | Loss: 3.0683
# Epoch 14 | Loss: 2.9502
# Epoch 15 | Loss: 2.8679
# Epoch 16 | Loss: 2.8400
# Epoch 17 | Loss: 2.8009
# Epoch 18 | Loss: 2.7901
# Epoch 19 | Loss: 2.7905
# Epoch 20 | Loss: 2.8086
# Epoch 21 | Loss: 2.7560
# Epoch 22 | Loss: 2.7267
# Epoch 23 | Loss: 2.7036
# Epoch 24 | Loss: 2.6911
# Epoch 25 | Loss: 2.6945
# [Asymmetric] APL_NCE_RCE Accuracy at 0.4 noise level: 32.50%
# [Asymmetric] Training APL_NFL_MAE at noise rate 0.4
# Epoch 1 | Loss: 0.6464
# Epoch 2 | Loss: 0.4970
# Epoch 3 | Loss: 0.4392
# Epoch 4 | Loss: 0.4040
# Epoch 5 | Loss: 0.3781
# Epoch 6 | Loss: 0.3543
# Epoch 7 | Loss: 0.3356
# Epoch 8 | Loss: 0.3177
# Epoch 9 | Loss: 0.3017
# Epoch 10 | Loss: 0.2869
# Epoch 11 | Loss: 0.2754
# Epoch 12 | Loss: 0.2590
# Epoch 13 | Loss: 0.2449
# Epoch 14 | Loss: 0.2331
# Epoch 15 | Loss: 0.2202
# Epoch 16 | Loss: 0.2095
# Epoch 17 | Loss: 0.1979
# Epoch 18 | Loss: 0.1850
# Epoch 19 | Loss: 0.1768
# Epoch 20 | Loss: 0.1655
# Epoch 21 | Loss: 0.1595
# Epoch 22 | Loss: 0.1532
# Epoch 23 | Loss: 0.1500
# Epoch 24 | Loss: 0.1471
# Epoch 25 | Loss: 0.1468
# [Asymmetric] APL_NFL_MAE Accuracy at 0.4 noise level: 74.36%
